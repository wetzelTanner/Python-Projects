# %% [markdown]
# <h1><center>Access Data From A DataFrame</center></h1>

# %% [markdown]
# ## Prep: Import pandas package and read the dataset into a DataFrame.

# %% [markdown]
# The `read_csv()` function can also understand the csv files hosted on the Internet. You just need to supply the URL to the file.
#
# For example, given the same file hosted on Github: https://raw.githubusercontent.com/BlueJayADAL/CS121/main/datasets/nfl_height_weight.csv

# %%
import pandas as pd

# %%
file_url = 'https://raw.githubusercontent.com/BlueJayADAL/CS121/main/datasets/nfl_height_weight.csv'
df = pd.read_csv(file_url)

# %%
# Show the top 5 rows from the dataframe
df.head()
# Out:
#    number            full_name position  height_in_inches  weight_in_lbs  \
# 0      23       Alford, Robert       CB                70            186
# 1      95  Babineaux, Jonathan       DT                74            300
# 2      72           Baker, Sam        T                77            301
# 3      59         Bartu, Joplo      OLB                74            230
# 4      71       Biermann, Kroy      OLB                75            255
#
#   date_of_birth team
# 0     11/1/1988  ATL
# 1    10/12/1981  ATL
# 2     5/30/1985  ATL
# 3     10/3/1990  ATL
# 4     9/12/1985  ATL

# %% [markdown]
# ## Section 1: Access the columns or rows from a DataFrame

# %% [markdown]
# #### Access a single column
#
# Subscript a DataFrame by a column name to get the contents of that column. It's very similar to accessing values from a dictionary.

# %%
# Select only the position column

df['position']
# Out:
# 0        CB
# 1        DT
# 2         T
# 3       OLB
# 4       OLB
#        ...
# 1869      G
# 1870     OT
# 1871    OLB
# 1872     RB
# 1873     QB
# Name: position, Length: 1874, dtype: object

# %% [markdown]
# #### Access a single row (entry) with positional index
#
# Subscript a DataFrame by a row index with the `.iloc` attribute to get the contents of that row.

# %%
df.iloc[0]
# Out:
# number                          23
# full_name           Alford, Robert
# position                        CB
# height_in_inches                70
# weight_in_lbs                  186
# date_of_birth            11/1/1988
# team                           ATL
# Name: 0, dtype: object

# %% [markdown]
# ####  Access a single row with a descriptive row name.
#
# Run the cell below to have a different looking DataFrame that has player's full name as the row index.

# %%
df2 = df.set_index('full_name')


df2.head()
# Out:
#                      number position  height_in_inches  weight_in_lbs  \
# full_name
# Alford, Robert           23       CB                70            186
# Babineaux, Jonathan      95       DT                74            300
# Baker, Sam               72        T                77            301
# Bartu, Joplo             59      OLB                74            230
# Biermann, Kroy           71      OLB                75            255
#
#                     date_of_birth team
# full_name
# Alford, Robert          11/1/1988  ATL
# Babineaux, Jonathan    10/12/1981  ATL
# Baker, Sam              5/30/1985  ATL
# Bartu, Joplo            10/3/1990  ATL
# Biermann, Kroy          9/12/1985  ATL

# %% [markdown]
# Now we can subscript the DataFrame `df2` by a row name with the `.loc` attribute to get the contents of that row:
# `df2.loc['Alford, Robert']`

# %%
df2.loc['Alford, Robert']
# Out:
# number                     23
# position                   CB
# height_in_inches           70
# weight_in_lbs             186
# date_of_birth       11/1/1988
# team                      ATL
# Name: Alford, Robert, dtype: object

# %% [markdown]
# It's worth mentioning that the positional row indices still exist.

# %%
df2.iloc[0]
# Out:
# number                     23
# position                   CB
# height_in_inches           70
# weight_in_lbs             186
# date_of_birth       11/1/1988
# team                      ATL
# Name: Alford, Robert, dtype: object

# %% [markdown]
# #### Access multiple discrete columns
#
# What if we want to access multiple columns? No problem, provide a `list` of column names in the subscript

# %%
df[['height_in_inches', 'weight_in_lbs']]
# Out:
#       height_in_inches  weight_in_lbs
# 0                   70            186
# 1                   74            300
# 2                   77            301
# 3                   74            230
# 4                   75            255
# ...                ...            ...
# 1869                75            303
# 1870                78            314
# 1871                73            237
# 1872                71            215
# 1873                76            217
#
# [1874 rows x 2 columns]

# %% [markdown]
# #### Access multiple discrete rows
#
# What if we want to access multiple rows? Likewise, provide a `list` of column names to the `iloc[]` or `loc[]` attribute

# %%
df.iloc[[0, 2, 10]]
# Out:
#     number       full_name position  height_in_inches  weight_in_lbs  \
# 0       23  Alford, Robert       CB                70            186
# 2       72      Baker, Sam        T                77            301
# 10      15     Cone, Kevin       WR                74            216
#
#    date_of_birth team
# 0      11/1/1988  ATL
# 2      5/30/1985  ATL
# 10     3/20/1988  ATL

# %% [markdown]
# #### Exercise: Grab the same rows out as above from `df2` but by using `loc[]`

# %%
df2.loc[['Alford, Robert', 'Baker, Sam', 'Cone, Kevin']]
# Out:
#                 number position  height_in_inches  weight_in_lbs  \
# full_name
# Alford, Robert      23       CB                70            186
# Baker, Sam          72        T                77            301
# Cone, Kevin         15       WR                74            216
#
#                date_of_birth team
# full_name
# Alford, Robert     11/1/1988  ATL
# Baker, Sam         5/30/1985  ATL
# Cone, Kevin        3/20/1988  ATL

# %% [markdown]
# ## Section 2: Slice a contiguous range of data in DataFrames

# %% [markdown]
# #### Slice DataFrame `df` with row indices range from 10 to 19.
#
# *Note: the range rule still applies for `iloc[]`: inclusive for the beginning index and exclusive for the ending index*

# %%
df.iloc[10:20]
# Out:
#     number          full_name position  height_in_inches  weight_in_lbs  \
# 10      15        Cone, Kevin       WR                74            216
# 11       4   Davis, Dominique       QB                75            210
# 12      19        Davis, Drew       WR                73            205
# 13      28     DeCoud, Thomas       FS                74            192
# 14      52        Dent, Akeem      MLB                73            239
# 15      42   DiMarco, Patrick       FB                73            234
# 16      83     Douglas, Harry       WR                72            183
# 17      34      Ewing, Bradie       FB                71            243
# 18      24  Franks, Dominique       DB                72            197
# 19      53      Gaither, Omar      MLB                74            235
#
#    date_of_birth team
# 10     3/20/1988  ATL
# 11     7/17/1989  ATL
# 12      1/4/1989  ATL
# 13     3/19/1985  ATL
# 14     9/27/1987  ATL
# 15     4/30/1989  ATL
# 16     9/16/1984  ATL
# 17    12/26/1989  ATL
# 18     10/8/1987  ATL
# 19     3/18/1984  ATL

# %% [markdown]
# #### Slice DataFrame `df2` with player's full name from `Cone, Kevin` to `Gaither, Omar`
#
# *Note: the range rule does NOT apply for `loc[]` since you are using descriptive indices*

# %%
df2.loc['Cone, Kevin':'Gaither, Omar']
# Out:
#                    number position  height_in_inches  weight_in_lbs  \
# full_name
# Cone, Kevin            15       WR                74            216
# Davis, Dominique        4       QB                75            210
# Davis, Drew            19       WR                73            205
# DeCoud, Thomas         28       FS                74            192
# Dent, Akeem            52      MLB                73            239
# DiMarco, Patrick       42       FB                73            234
# Douglas, Harry         83       WR                72            183
# Ewing, Bradie          34       FB                71            243
# Franks, Dominique      24       DB                72            197
# Gaither, Omar          53      MLB                74            235
#
#                   date_of_birth team
# full_name
# Cone, Kevin           3/20/1988  ATL
# Davis, Dominique      7/17/1989  ATL
# Davis, Drew            1/4/1989  ATL
# DeCoud, Thomas        3/19/1985  ATL
# Dent, Akeem           9/27/1987  ATL
# DiMarco, Patrick      4/30/1989  ATL
# Douglas, Harry        9/16/1984  ATL
# Ewing, Bradie        12/26/1989  ATL
# Franks, Dominique     10/8/1987  ATL
# Gaither, Omar         3/18/1984  ATL

# %% [markdown]
# #### You can even use `loc[]` and `iloc[]` to select a subset of columns from the sliced data. Just use a comma to separate the row part and the column part.

# %%
# When using iloc[], both row indices and column names must be positional

df2.iloc[10:19, 2:5]
# Out:
#                    height_in_inches  weight_in_lbs date_of_birth
# full_name
# Cone, Kevin                      74            216     3/20/1988
# Davis, Dominique                 75            210     7/17/1989
# Davis, Drew                      73            205      1/4/1989
# DeCoud, Thomas                   74            192     3/19/1985
# Dent, Akeem                      73            239     9/27/1987
# DiMarco, Patrick                 73            234     4/30/1989
# Douglas, Harry                   72            183     9/16/1984
# Ewing, Bradie                    71            243    12/26/1989
# Franks, Dominique                72            197     10/8/1987

# %% [markdown]
# #### Exercise: Slice the same data out as above from `df2` but by using `loc[]`

# %%
df2.loc['Cone, Kevin':'Gaither, Omar', 'position':'weight_in_lbs']
# Out:
#                   position  height_in_inches  weight_in_lbs
# full_name
# Cone, Kevin             WR                74            216
# Davis, Dominique        QB                75            210
# Davis, Drew             WR                73            205
# DeCoud, Thomas          FS                74            192
# Dent, Akeem            MLB                73            239
# DiMarco, Patrick        FB                73            234
# Douglas, Harry          WR                72            183
# Ewing, Bradie           FB                71            243
# Franks, Dominique       DB                72            197
# Gaither, Omar          MLB                74            235

# %% [markdown]
# ## Section 3: Data filtering (boolean selection) in DataFrames

# %% [markdown]
# #### Find the players that are more than 80 inches tall.

# %%
# Step1: Create a boolean filter
bool_filter = df['height_in_inches'] > 80


# Show bool_filter
bool_filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1869    False
# 1870    False
# 1871    False
# 1872    False
# 1873    False
# Name: height_in_inches, Length: 1874, dtype: bool

# %%
# Step2: Place the boolean filter in subscript to select 
#        only the data with boolean being True

df[bool_filter]
# Out:
#       number      full_name position  height_in_inches  weight_in_lbs  \
# 1351      77   Dunlap, King        T                81            330
# 1593      69  Dotson, Demar        T                81            315
#
#      date_of_birth team
# 1351     9/14/1985   SD
# 1593    10/11/1985   TB

# %% [markdown]
# #### Exercise: Find the players that are less than 170 lbs in weight

# %%
bool_filter = df['weight_in_lbs'] < 170

# %%
df[bool_filter]
# Out:
#     number       full_name position  height_in_inches  weight_in_lbs  \
# 98      37  Robey, Nickell       DB                67            165
#
#    date_of_birth team
# 98     1/17/1992  BUF

# %% [markdown]
# #### Exercise: Find the players from your favorite team!

# %%
bool_filter = df['team'] == 'BAL'

# %%
df[bool_filter]
# Out:
#      number          full_name position  height_in_inches  weight_in_lbs  \
# 292      59      Brown, Arthur      ILB                72            235
# 293      23      Brown, Chykie       DB                71            190
# 294      14      Brown, Marlon       WR                76            205
# 295      49       Bryant, D.J.       LB                75            248
# 296      56        Bynes, Josh      ILB                73            240
# 297      99       Canty, Chris       DE                79            317
# 298      87      Clark, Dallas       TE                75            252
# 299      62     Cody, Terrence       NT                76            340
# 300      46        Cox, Morgan       LS                76            241
# 301      84        Dickson, Ed       TE                76            255
# 302      17       Doss, Tandon       WR                74            207
# 303      58    Dumervil, Elvis      OLB                71            260
# 304      26         Elam, Matt       FS                70            210
# 305       5        Flacco, Joe       QB                78            245
# 306      66   Gradkowski, Gino        C                75            300
# 307      24      Graham, Corey       CB                72            196
# 308      95   Hamilton, Adrian       LB                75            255
# 309      29      Huff, Michael       FS                72            211
# 310      32    Ihedigbo, James       SS                73            214
# 311      25       Jackson, Asa       CB                70            182
# 312      77       Jensen, Ryan        C                76            318
# 313      97      Jones, Arthur       DE                75            315
# 314      12      Jones, Jacoby       WR                74            215
# 315      40     Juszczyk, Kyle       RB                73            245
# 316       4          Koch, Sam        P                73            218
# 317      44       Leach, Vonta       FB                72            260
# 318      41    Levine, Anthony       DB                71            203
# 319      53    McClain, Jameel      ILB                73            245
# 320      50  McClellan, Albert      OLB                74            245
# 321      78   McKinnie, Bryant        T                80            352
# 322      90    McPhee, Pernell       LB                75            280
# 323      13    Mellette, Aaron       WR                74            217
# 324      36      Miles, Jeromy       SS                74            214
# 325      60     Monroe, Eugene        T                77            306
# 326      92      Ngata, Haloti       NT                76            340
# 327      74      Oher, Michael        T                76            315
# 328      72   Osemele, Kelechi        G                77            330
# 329      30    Pierce, Bernard       RB                72            218
# 330      88      Pitta, Dennis       TE                76            245
# 331      76          Reid, Jah        T                79            340
# 332      27          Rice, Ray       RB                68            212
# 333      68      Shipley, A.Q.        C                73            309
# 334      94        Simon, John       LB                73            257
# 335      22       Smith, Jimmy       CB                74            200
# 336      51       Smith, Daryl      ILB                74            248
# 337      82      Smith, Torrey       WR                72            205
# 338      96     Spears, Marcus       DE                76            315
# 339      80   Stokley, Brandon       WR                72            194
# 340      55     Suggs, Terrell      OLB                75            260
# 341       2      Taylor, Tyrod       QB                73            215
# 342      83   Thompson, Deonte       WR                72            203
# 343       9     Tucker, Justin        K                72            180
# 344      93    Tyson, DeAngelo       DE                74            315
# 345      91   Upshaw, Courtney      OLB                74            272
# 346      71      Wagner, Ricky       OT                78            310
# 347      21    Webb, Lardarius       CB                70            182
# 348      98  Williams, Brandon       DT                73            335
# 349      73     Yanda, Marshal        G                75            305
#
#     date_of_birth team
# 292     6/17/1990  BAL
# 293    12/26/1986  BAL
# 294     4/22/1991  BAL
# 295      3/3/1989  BAL
# 296     8/24/1989  BAL
# 297    11/10/1982  BAL
# 298     6/12/1979  BAL
# 299     6/28/1988  BAL
# 300     4/26/1986  BAL
# 301     7/25/1987  BAL
# 302     9/22/1989  BAL
# 303     1/19/1984  BAL
# 304     9/21/1991  BAL
# 305     1/16/1985  BAL
# 306     11/5/1988  BAL
# 307     7/25/1985  BAL
# 308    11/29/1987  BAL
# 309      3/6/1983  BAL
# 310     12/3/1983  BAL
# 311     12/2/1989  BAL
# 312     5/27/1991  BAL
# 313      6/3/1986  BAL
# 314     7/11/1984  BAL
# 315     4/23/1991  BAL
# 316     8/13/1982  BAL
# 317     11/6/1981  BAL
# 318     3/27/1987  BAL
# 319     7/25/1985  BAL
# 320      6/4/1986  BAL
# 321     9/23/1979  BAL
# 322    12/17/1988  BAL
# 323    12/28/1989  BAL
# 324     7/20/1987  BAL
# 325     4/18/1987  BAL
# 326     1/21/1984  BAL
# 327     5/28/1986  BAL
# 328     6/24/1989  BAL
# 329     5/10/1990  BAL
# 330     6/29/1985  BAL
# 331     7/21/1988  BAL
# 332     1/22/1987  BAL
# 333     5/22/1986  BAL
# 334    10/14/1990  BAL
# 335     7/26/1988  BAL
# 336     3/14/1982  BAL
# 337     1/26/1989  BAL
# 338      3/8/1983  BAL
# 339     6/23/1976  BAL
# 340    10/11/1982  BAL
# 341      8/3/1989  BAL
# 342     2/14/1989  BAL
# 343    11/21/1989  BAL
# 344     4/12/1989  BAL
# 345    12/13/1989  BAL
# 346    10/21/1989  BAL
# 347    10/12/1985  BAL
# 348     2/21/1989  BAL
# 349     9/15/1984  BAL

# %% [markdown]
# #### Exercise: Pinpoint your favorite player - `Brady, Tom`!

# %%
# Old data alert!
# Now should be in team 'Tampa Bay Buccaneers' - TB

bool_filter = df['full_name'] == 'Brady, Tom'
df[bool_filter]
# Out:
#      number   full_name position  height_in_inches  weight_in_lbs  \
# 995      12  Brady, Tom       QB                76            225
#
#     date_of_birth team
# 995      8/3/1977   NE

# %% [markdown]
# #### How to apply multiple conditions for the data filtering?
#
# For example, find all players whose height are over 78 inches from `PHI` Eagles.

# %%
bool_filter1 = df['height_in_inches'] > 78


bool_filter2 = df['team'] == 'PHI'

# %%
# filter_final = bool_filter1 and bool_filter2 will fail

filter_final = bool_filter1 & bool_filter2

# %%
df[filter_final]
# Out:
#       number          full_name position  height_in_inches  weight_in_lbs  \
# 1245      90  Geathers, Clifton       DE                80            340
# 1257      67      Kelly, Dennis        T                80            321
#
#      date_of_birth team
# 1245    12/11/1987  PHI
# 1257     1/16/1990  PHI

# %% [markdown]
# ## Section 4: Handle Missing Data

# %% [markdown]
# Given the dataset from following URL (run the cell below):

# %%
url = 'https://raw.githubusercontent.com/BlueJayADAL/DS200/master/datasets/weather_data.csv'

# %% [markdown]
# Read in the data into a DataFrame named `weather`

# %%
weather = pd.read_csv(url)

# %%
weather
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# #### Show the missing data with `info()` method

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          9 non-null      object
#  1   temperature  5 non-null      float64
#  2   windspeed    5 non-null      float64
#  3   event        7 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 416.0+ bytes

# %% [markdown]
# #### Show how many data are missing from each column.

# %%
weather.isnull().sum()
# Out:
# day            0
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %% [markdown]
# #### Drop any rows with at least 1 missing data

# %%
weather.dropna()
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# *Note: the change is NOT happening in place unless specify `inplace=True`*

# %%
# weather still has 9 entries since last line 
# of code didn't actually change the data

weather
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# #### Drop any columns with at least 1 missing data

# %%
weather.dropna(axis = 1)
# Out:
#          day
# 0   1/1/2017
# 1   1/4/2017
# 2   1/5/2017
# 3   1/6/2017
# 4   1/7/2017
# 5   1/8/2017
# 6   1/9/2017
# 7  1/10/2017
# 8  1/11/2017

# %% [markdown]
# #### Set a dropping threshold. Keep only the rows that have at least the threshold number of non-missing values.

# %%
weather.dropna(thresh = 3)
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 4   1/7/2017         32.0        NaN    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# #### Fill all NaNs with one specific value, e.g. 0.

# %%
weather.fillna(value = 0)
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          0.0        9.0   Sunny
# 2   1/5/2017         28.0        0.0    Snow
# 3   1/6/2017          0.0        7.0       0
# 4   1/7/2017         32.0        0.0    Rain
# 5   1/8/2017          0.0        0.0   Sunny
# 6   1/9/2017          0.0        0.0       0
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# #### Fill the NaN with 0 just for columns `temperature` and `windspeed`

# %%
weather[['temperature', 'windspeed']].fillna(value = 0)
# Out:
#    temperature  windspeed
# 0         32.0        6.0
# 1          0.0        9.0
# 2         28.0        0.0
# 3          0.0        7.0
# 4         32.0        0.0
# 5          0.0        0.0
# 6          0.0        0.0
# 7         34.0        8.0
# 8         40.0       12.0

# %% [markdown]
# #### However, sometimes 0 is not the best guess. Let's use average temperature and median windspeed to fill the NaNs.

# %%
avg_temp = weather['temperature'].mean()

median_wind = weather['windspeed'].median()


print(avg_temp, median_wind)
# Out:
# 33.2 8.0

# %%
weather['temperature'] = weather['temperature'].fillna(value = avg_temp)

weather['windspeed'] = weather['windspeed'].fillna(value = median_wind)

# %%
weather
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         33.2        9.0   Sunny
# 2   1/5/2017         28.0        8.0    Snow
# 3   1/6/2017         33.2        7.0     NaN
# 4   1/7/2017         32.0        8.0    Rain
# 5   1/8/2017         33.2        8.0   Sunny
# 6   1/9/2017         33.2        8.0     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# #### Propagate NaN values with forward fill

# %%
#  propagate NaN with forward fill.
new_df = weather.ffill()

new_df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         33.2        9.0   Sunny
# 2   1/5/2017         28.0        8.0    Snow
# 3   1/6/2017         33.2        7.0    Snow
# 4   1/7/2017         32.0        8.0    Rain
# 5   1/8/2017         33.2        8.0   Sunny
# 6   1/9/2017         33.2        8.0   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %% [markdown]
# #### Propagate NaN values with backward fill

# %%
#  propagate NaN with backward fill.
new_df = weather.backfill()

new_df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         33.2        9.0   Sunny
# 2   1/5/2017         28.0        8.0    Snow
# 3   1/6/2017         33.2        7.0    Rain
# 4   1/7/2017         32.0        8.0    Rain
# 5   1/8/2017         33.2        8.0   Sunny
# 6   1/9/2017         33.2        8.0  Cloudy
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
